# %% [markdown]
# A context manager is a tool in Python that automatically manages setup and cleanup actions — most commonly used when working with files, network connections, locks, or database connections.
#
# * No need to manually call `file.close()`
# * Even if an error happens inside the `with` block, the file will be closed properly.
#
# ```python
# with open("example.txt", "r") as file:
#     content = file.read()
# ```
