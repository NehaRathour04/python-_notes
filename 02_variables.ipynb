# %% [markdown]
# A variable is a container used to store data (values) in a program.
# value can vary(change)
# var = value
# name = "Alice"
# age = 25
# is_active = True

# %% [markdown]
# Identifiers are the names given to variables, functions, classes, etc. in a program.

# %% [markdown]
# ```python
# keywords are the reserved words that have special meaning and serve specific purpose in language syntax.
# they can't be used as a variable,function or class
# there are 35 keywords in python
# some of which are
# if elif else
# for while
# break continue pass
# class def return
# global
# in is
# as from
# import
# True False
# None
# and or not
# try except finally raise
# lambda
# with
# match
# case
# yield
# del   - delete a objects e.g. del x[1]
#
# assert - for debugging test if condition is true ,if not raise AssertionError
# async await - These are used for asynchronous programming (handling tasks like web requests or file reads without blocking the whole program).
# ```

# %%
import keyword
print(len(keyword.kwlist))
print((keyword.kwlist))
# Out:
# 35
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# constants in python
# not have dedicated syntax but you can write a constant in UPPERCASE to let developer understand you shouldn't change its value
